# %%
# Load necessary libraries
library(ADM)
source("../functions.R")
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘uwot’
#
#
# The following object is masked from ‘package:umap’:
#
#     umap
#
#
# Loading required package: MASS
#
# Loading required package: survival
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Package 'mclust' version 6.1.1
# Type 'citation("mclust")' for citing this R package in publications.
#
#
# Attaching package: ‘tidyr’
#
#
# The following object is masked from ‘package:magrittr’:
#
#     extract
#
#
# The following object is masked from ‘package:igraph’:
#
#     crossing
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘aricode’
#
#
# The following object is masked from ‘package:MixGHD’:
#
#     ARI

# %%
# Set dataset name
dataset = "Oihane"  # Options: Gutierrez, Oihane, Quake, Brain5k, mir, Spleen, metabolism, gene

# Load data
dataload = dataloader(dataset)
dat = dataload$dat
info = dataload$info
k = length(unique(info))
label_mapping <- get_mapping(dataset)
print("load data successfully!")

# Execute candidate visualization methods
candidate.out = candidate.visual(dat, dim = 3, method=c("PCA", "MDS", "iMDS", "Sammon", "HLLE", "Isomap", 
                                                  "kPCA", "LEIM", "UMAP", "tSNE","PHATE","KEF"),tsne.perplexity = c(10, 30))

print("Indivadual methods completed!!")
# Extract results
e<-candidate.out[[1]]  # Visualization results
names_list = candidate.out[[2]]  # List of method names
# Out:
# [1] "load data successfully!"
# [1] 1337  213
# [1] "PCA calculating..."
# [1] "MDS calculating..."
# [1] "iMDS calculating..."
# initial  value 25.421213
# iter   5 value 18.167995
# iter  10 value 15.651792
# iter  15 value 14.718168
# iter  20 value 14.164216
# iter  25 value 13.875477
# iter  30 value 13.704774
# final  value 13.632977
# converged
# [1] "Sammon calculating..."
# Initial stress        : 0.26272
# stress after   1 iters: 0.26020
# [1] "HLLE calculating..."
# 2024-10-16 17:22:14.352721: Finding nearest neighbors
#
# 2024-10-16 17:22:14.678629: Calculating Hessian
# 1337/1337
# 'as(<dsCMatrix>, "dgCMatrix")' is deprecated.
# Use 'as(., "generalMatrix")' instead.
# See help("Deprecated") and help("Matrix-deprecated").
#
# 2024-10-16 17:22:15.514184: Embedding
#
# Eigenvalues:  2.310002e-02  2.281269e-02  1.742056e-02 -6.908740e-17
#
# 2024-10-16 17:22:15.554296: DONE
# [1] "Isomap calculating..."
# 2024-10-16 17:22:15.568284: Isomap START
#
# 2024-10-16 17:22:15.57061: constructing knn graph
#
# 2024-10-16 17:22:15.959965: calculating geodesic distances
#
# 2024-10-16 17:22:16.907813: Classical Scaling
# [1] "kPCA calculating..."
# 2024-10-16 17:22:16.94819: Calculating kernel PCA
#
# 2024-10-16 17:22:18.426311: Trying to calculate reverse
#
# 2024-10-16 17:22:23.759887: DONE
# [1] "kPCA calculating..."
# 2024-10-16 17:22:23.78284: Calculating kernel PCA
#
# 2024-10-16 17:22:25.430268: Trying to calculate reverse
#
# 2024-10-16 17:22:30.843187: DONE
# [1] "LEIM calculating..."
# 2024-10-16 17:22:30.860269: Creating weight matrix
#
# 2024-10-16 17:22:31.274485: Eigenvalue decomposition
#
# Eigenvalues:  5.169424e-02  3.230618e-02  1.809466e-02 -6.434909e-17
#
# 2024-10-16 17:22:31.318579: DONE
# [1] "UMAP calculating..."
# [1] "UMAP calculating..."
# [1] "tSNE calculating..."
# [1] "tSNE calculating..."
# [1] "PHATE calculating..."
# [1] "PHATE calculating..."
# [1] "KEF calculating..."
# NULL
# [1] "Indivadual methods completed!!"

# %%
# set.seed(2024)
# Execute meta-spec visualization
ensemble.out = ensemble.viz(e, names(e))
print("meta-spec completed!!")
# Out:
# [1] "1000 samples done!"
# [1] "meta-spec completed!!"

# %%
# Execute ADM method
adm.out = adm(e,distr.template = "combine")
print("ADM completed!!")
# Out:
# [1] "working on ADM..."
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# [1] "ADM completed!!"

# %%
# Define color list for visualization
color_list =c("#FB6A4A","#54278F","#006635","#3182BD","#DE2D26","#72A34F","#5D7AD3", "#756BB1","#FCAE91","#fe87ac","#AFABAB","#67A9CF","#CBC9E2","#4d982e","#E6873E","#545454","#aa3474","#ee8c7d","#2e5fa1","#FDD0A3","#C22F2F","#036f73")

# Process and visualize meta-method results
result = process_and_visualize_meta_methods(adm.out, ensemble.out,info, k, color_list)
# Out:
# [1] "Running R version:4.3.1"
# ****** meta-spec ******
#         ARI       NMI
# 1 0.4070989 0.5517799
# ****** ADM ******
#         ARI       NMI
# 1 0.5927403 0.6840859

# %%
result$ARI_list
# Out:
# [[1]]
#         ARI       NMI
# 1 0.4070989 0.5517799
#
# [[2]]
#         ARI       NMI
# 1 0.5927403 0.6840859

# %%
result$plot
# Out:
# [[1]]
#
# [[2]]
# NULL
#
# [[3]]
# plot without title
# plot without title

# %%
# Visualize individual method results
ind_result = visualize_individual_methods(e, names_list, info, color_list, k)
# Out:
# ****** PCA ******
#         ARI       NMI
# 1 0.2834848 0.4550086
# Average Silhouette Width: 0.3929314
#
# ****** MDS ******
#         ARI       NMI
# 1 0.3075343 0.4803112
# Average Silhouette Width: 0.4213024
# plot without title
# ****** iMDS ******
#         ARI       NMI
# 1 0.2318455 0.4122834
# Average Silhouette Width: 0.3935253
# plot without title
# ****** Sammon ******
#         ARI       NMI
# 1 0.3126338 0.4808689
# Average Silhouette Width: 0.4172605
# plot without title
# ****** HLLE ******
#         ARI       NMI
# 1 0.3648802 0.5353863
# Average Silhouette Width: 0.5416207
# plot without title
# ****** Isomap ******
#         ARI       NMI
# 1 0.5075882 0.6242941
# Average Silhouette Width: 0.4389707
# plot without title
# ****** kPCA1 ******
#         ARI       NMI
# 1 0.3104694 0.4809026
# Average Silhouette Width: 0.4169053
# plot without title
# ****** kPCA2 ******
#         ARI       NMI
# 1 0.3123427 0.4820549
# Average Silhouette Width: 0.4156878
# plot without title
# ****** LEIM ******
#         ARI       NMI
# 1 0.5214215 0.6658644
# Average Silhouette Width: 0.5433396
# plot without title
# ****** UMAP1 ******
#         ARI       NMI
# 1 0.5980032 0.6866163
# Average Silhouette Width: 0.5404649
# plot without title
# ****** UMAP2 ******
#         ARI       NMI
# 1 0.5651465 0.6711479
# Average Silhouette Width: 0.5213514
# plot without title
# ****** tSNE1 ******
#         ARI       NMI
# 1 0.7154668 0.7500159
# Average Silhouette Width: 0.498076
# plot without title
# ****** tSNE2 ******
#         ARI       NMI
# 1 0.6911708 0.7319011
# Average Silhouette Width: 0.513753
# plot without title
# ****** PHATE1 ******
#         ARI       NMI
# 1 0.5377268 0.6613318
# Average Silhouette Width: 0.5319609
# plot without title
# ****** PHATE2 ******
#         ARI       NMI
# 1 0.5629988 0.6614183
# Average Silhouette Width: 0.4957506
# plot without title
# ****** KEF ******
#         ARI       NMI
# 1 0.3782014 0.4801466
# Average Silhouette Width: 0.4172929
# plot without title
# plot without title

# %%
# View results
# Use the following commands to view numerical results and plots for each method:
# ind_result[[1]]$plot  # Plot
# ind_result[[1]]$ari   # ARI value
# ind_result[[1]]$nmi   # NMI value
# ind_result[[1]]$silhouette  # Silhouette coefficient

ind_result[[1]]
# Out:
# $plot
#
# $ari
# [1] 0.2834848
#
# $nmi
# [1] 0.4550086
#
# $silhouette
# [1] 0.3929314
# plot without title
