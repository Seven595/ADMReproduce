# %%
# Load necessary libraries
library(ADM)
source("../functions.R")
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘uwot’
#
#
# The following object is masked from ‘package:umap’:
#
#     umap
#
#
# Loading required package: MASS
#
# Loading required package: survival
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Package 'mclust' version 6.1.1
# Type 'citation("mclust")' for citing this R package in publications.
#
#
# Attaching package: ‘tidyr’
#
#
# The following object is masked from ‘package:magrittr’:
#
#     extract
#
#
# The following object is masked from ‘package:igraph’:
#
#     crossing
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘aricode’
#
#
# The following object is masked from ‘package:MixGHD’:
#
#     ARI

# %%
# Set dataset name
dataset = "Quake"  # Options: Gutierrez, Oihane, Quake, Brain5k, mir, Spleen, metabolism, gene

# Load data
dataload = dataloader(dataset)
dat = dataload$dat
info = dataload$info
k = length(unique(info))
label_mapping <- get_mapping(dataset)
print("load data successfully!")

# Execute candidate visualization methods
candidate.out = candidate.visual(dat, dim = 3, method=c("PCA", "MDS", "iMDS", "Sammon", "HLLE", "Isomap", 
                                                  "kPCA", "LEIM", "UMAP", "tSNE","PHATE","KEF"),tsne.perplexity = c(10, 30))

print("Indivadual methods completed!!")
# Extract results
e<-candidate.out[[1]]  # Visualization results
names_list = candidate.out[[2]]  # List of method names
# Out:
# [1] "load data successfully!"
# [1] 1676 3349
# [1] "PCA calculating..."
# [1] "MDS calculating..."
# [1] "iMDS calculating..."
# initial  value 30.105986
# final  value 30.104101
# converged
# [1] "Sammon calculating..."
# Initial stress        : 0.37818
# stress after   5 iters: 0.32726
# [1] "HLLE calculating..."
# 2024-10-16 17:01:54.081746: Finding nearest neighbors
#
# 2024-10-16 17:02:03.058706: Calculating Hessian
# 1676/1676
# 'as(<dsCMatrix>, "dgCMatrix")' is deprecated.
# Use 'as(., "generalMatrix")' instead.
# See help("Deprecated") and help("Matrix-deprecated").
#
# 2024-10-16 17:02:35.686305: Embedding
#
# Eigenvalues:  3.072724e-03  2.311533e-03  1.786727e-03 -6.915465e-16
#
# 2024-10-16 17:02:35.718758: DONE
# [1] "Isomap calculating..."
# 2024-10-16 17:02:35.793488: Isomap START
#
# 2024-10-16 17:02:35.796647: constructing knn graph
#
# 2024-10-16 17:02:45.237505: calculating geodesic distances
#
# 2024-10-16 17:02:46.593766: Classical Scaling
# [1] "kPCA calculating..."
# 2024-10-16 17:02:46.967286: Calculating kernel PCA
#
# 2024-10-16 17:02:50.060433: Trying to calculate reverse
#
# 2024-10-16 17:02:56.398993: DONE
# [1] "kPCA calculating..."
# 2024-10-16 17:02:56.463037: Calculating kernel PCA
#
# 2024-10-16 17:02:59.535158: Trying to calculate reverse
#
# 2024-10-16 17:03:05.945168: DONE
# [1] "LEIM calculating..."
# 2024-10-16 17:03:05.99948: Creating weight matrix
#
# 2024-10-16 17:03:17.00211: Eigenvalue decomposition
#
# Eigenvalues:  2.383979e-01  1.416211e-01  9.474165e-02 -7.204862e-17
#
# 2024-10-16 17:03:17.048585: DONE
# [1] "UMAP calculating..."
# [1] "UMAP calculating..."
# [1] "tSNE calculating..."
# [1] "tSNE calculating..."
# [1] "PHATE calculating..."
# [1] "PHATE calculating..."
# [1] "KEF calculating..."
# NULL
# [1] "Indivadual methods completed!!"

# %%
# Execute meta-spec visualization
# set.seed(2024)
ensemble.out = ensemble.viz(e, names(e))
print("meta-spec completed!!")
# Out:
# [1] "1000 samples done!"
# [1] "meta-spec completed!!"

# %%
# Execute ADM method
adm.out = adm(e,distr.template = "combine")
print("ADM completed!!")
# Out:
# [1] "working on ADM..."
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
#
#
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# Building distance matrix...
# [1] "ADM completed!!"

# %%
# Define color list for visualization
color_list =c("#FB6A4A","#54278F","#006635","#3182BD","#DE2D26","#72A34F","#5D7AD3", "#756BB1","#FCAE91","#fe87ac","#AFABAB","#67A9CF","#CBC9E2","#4d982e","#E6873E","#545454","#aa3474","#ee8c7d","#2e5fa1","#FDD0A3","#C22F2F","#036f73")

# Process and visualize meta-method results
result = process_and_visualize_meta_methods(adm.out, ensemble.out,info, k, color_list)
# Out:
# [1] "Running R version:4.3.1"
# ****** meta-spec ******
#       ARI      NMI
# 1 0.30962 0.510691
# ****** ADM ******
#         ARI      NMI
# 1 0.3086542 0.524329

# %%
result$ARI_list
# Out:
# [[1]]
#       ARI      NMI
# 1 0.30962 0.510691
#
# [[2]]
#         ARI      NMI
# 1 0.3086542 0.524329

# %%
result$plot
# Out:
# [[1]]
#
# [[2]]
# NULL
#
# [[3]]
# plot without title
# plot without title

# %%
# Visualize individual method results
ind_result = visualize_individual_methods(e, names_list, info, color_list, k)
# Out:
# ****** PCA ******
#         ARI       NMI
# 1 0.3096777 0.4710871
# Average Silhouette Width: 0.3874436
#
# ****** MDS ******
#         ARI       NMI
# 1 0.3339392 0.5076908
# Average Silhouette Width: 0.3929572
# plot without title
# ****** iMDS ******
#         ARI       NMI
# 1 0.3339392 0.5076908
# Average Silhouette Width: 0.392951
# plot without title
# ****** Sammon ******
#         ARI       NMI
# 1 0.3946683 0.5136094
# Average Silhouette Width: 0.3922431
# plot without title
# ****** HLLE ******
#         ARI        NMI
# 1 0.0338868 0.08357261
# Average Silhouette Width: 0.6287886
# plot without title
# ****** Isomap ******
#         ARI       NMI
# 1 0.3090651 0.4799843
# Average Silhouette Width: 0.5164589
# plot without title
# ****** kPCA1 ******
#         ARI       NMI
# 1 0.1418276 0.3424597
# Average Silhouette Width: 0.3654311
# plot without title
# ****** kPCA2 ******
#          ARI       NMI
# 1 0.08989083 0.1035866
# Average Silhouette Width: 0.755876
# plot without title
# ****** LEIM ******
#         ARI       NMI
# 1 0.4465772 0.5587858
# Average Silhouette Width: 0.4452525
# plot without title
# ****** UMAP1 ******
#         ARI       NMI
# 1 0.4709557 0.5734796
# Average Silhouette Width: 0.4906671
# plot without title
# ****** UMAP2 ******
#         ARI       NMI
# 1 0.4495648 0.5621243
# Average Silhouette Width: 0.4616504
# plot without title
# ****** tSNE1 ******
#         ARI       NMI
# 1 0.3567387 0.5314975
# Average Silhouette Width: 0.3771478
# plot without title
# ****** tSNE2 ******
#         ARI       NMI
# 1 0.3216104 0.5167436
# Average Silhouette Width: 0.3309534
# plot without title
# ****** PHATE1 ******
#         ARI       NMI
# 1 0.5022449 0.6286991
# Average Silhouette Width: 0.4919664
# plot without title
# ****** PHATE2 ******
#         ARI       NMI
# 1 0.5281917 0.6210885
# Average Silhouette Width: 0.5229153
# plot without title
# ****** KEF ******
#         ARI       NMI
# 1 0.2868825 0.4144132
# Average Silhouette Width: 0.435864
# plot without title
# plot without title

# %%
# View results
# Use the following commands to view numerical results and plots for each method:
# ind_result[[1]]$plot  # Plot
# ind_result[[1]]$ari   # ARI value
# ind_result[[1]]$nmi   # NMI value
# ind_result[[1]]$silhouette  # Silhouette coefficient

ind_result[[1]]
# Out:
# $plot
#
# $ari
# [1] 0.3096777
#
# $nmi
# [1] 0.4710871
#
# $silhouette
# [1] 0.3874436
# plot without title
